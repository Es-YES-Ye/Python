# %% [markdown]
# <a href="https://colab.research.google.com/github/Es-YES-Ye/Python/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%ED%95%A8%EC%88%98(%ED%8C%8C%EC%9D%BC%EC%B2%98%EB%A6%AC).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #raw 한 파일 입출력

# %%
#read 모드로 열기

fp='/content/drive/MyDrive/새싹프로그램_파이썬데이터/aaa.txt'
fs=open(fp,'r')
data=fs.read()
fs.close()
print(data)
# Out:
# 열받게하지마
# 12345678
# abcdefg

# %%
#write 모드로 열면 그 이름으로 파일이 만들어진다
#원래 있었던 파일이면 그 파일이 지워지고 덮어쓰기가 된다

fp='/content/drive/MyDrive/새싹프로그램_파이썬데이터/aaa2.txt'
fs=open(fp,'w')
fs.write('장난하니?????')
fs.close()

# %%
fp='/content/drive/MyDrive/새싹프로그램_파이썬데이터/aaa2.txt'
fs=open(fp,'r')
data=fs.read()
fs.close()
print(data)
# Out:
# 장난하니?????

# %% [markdown]
# #맛보기
#
# mushroom.csv 파일을 이용해서

# %%
import pandas as pd
mr = pd.read_csv('/content/drive/MyDrive/새싹프로그램_파이썬데이터/mushrooms.csv')
mr
# Out:
#      class cap-shape cap-surface  ... spore-print-color population habitat
# 0        p         x           s  ...                 k          s       u
# 1        e         x           s  ...                 n          n       g
# 2        e         b           s  ...                 n          n       m
# 3        p         x           y  ...                 k          s       u
# 4        e         x           s  ...                 n          a       g
# ...    ...       ...         ...  ...               ...        ...     ...
# 8119     e         k           s  ...                 b          c       l
# 8120     e         x           s  ...                 b          v       l
# 8121     e         f           s  ...                 b          c       l
# 8122     p         k           y  ...                 w          v       l
# 8123     e         x           s  ...                 o          c       l
#
# [8124 rows x 23 columns]

# %%
#추출

mcs = mr['class']
mcs
# Out:
# 0       p
# 1       e
# 2       e
# 3       p
# 4       e
#        ..
# 8119    e
# 8120    e
# 8121    e
# 8122    p
# 8123    e
# Name: class, Length: 8124, dtype: object
